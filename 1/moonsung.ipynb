# %% [markdown]
# <a href="https://colab.research.google.com/github/moonsunglab/test/blob/main/1/moonsung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import folium
from folium.plugins import HeatMap
from shapely.geometry import box
import geopandas as gpd
from collections import defaultdict

# %% [markdown]
# # 로드킬

# %% [markdown]
# ## 로드킬 데이터 생성

# %%
file_path = 'https://github.com/LeeMinJun0102/test/raw/refs/heads/main/README.md'

# %%
rk_df = pd.read_csv(file_path, sep='\t', names=['number', 'road_kill', 'address', '날짜', '시간', '지역', '경도', '위도'], skiprows=1)
# 마지막 행 제거
rk_df = rk_df[:-1]
# 연도만 담고 있는 파생변수 생성
rk_df['연도'] = rk_df['날짜'].str.split('-').str[0]

# %%
rk_df
# Out:
#      number road_kill                                      address  \
# 0      3974       로드킬     경기 남양주시 와부읍 덕소리 392-2 번지에서 로드킬이 발생하였습니다.
# 1      3973       로드킬    세종특별자치시 연동면 합강리 526-11 번지에서 로드킬이 발생하였습니다.
# 2      3972       로드킬     세종특별자치시 연동면 합강리 96-13 번지에서 로드킬이 발생하였습니다.
# 3      3971       로드킬           대전 대덕구 미호동 1-10 번지에서 로드킬이 발생하였습니다.
# 4      3970       로드킬         세종특별자치시 가람동 245-5 번지에서 로드킬이 발생하였습니다.
# ...     ...       ...                                          ...
# 9476      5       로드킬      충남 청양군 청양읍 읍내리 183-4 번지에서 로드킬이 발생하였습니다.
# 9477      4       로드킬         강원 강릉시 포남동 1096-8 번지에서 로드킬이 발생하였습니다.
# 9478      3       로드킬  경기 용인시 기흥구 보정동 1019-1003 번지에서 로드킬이 발생하였습니다.
# 9479      2       로드킬        경기 용인시 기흥구 서천동 733 번지에서 로드킬이 발생하였습니다.
# 9480      1       로드킬     경기 안성시 양성면 이현리 산 23-1 번지에서 로드킬이 발생하였습니다.
#
#               날짜     시간           지역          경도         위도    연도
# 0     2020-12-31  18:41      경기 남양주시  127.214314  37.593123  2020
# 1     2020-12-31  18:17  세종특별자치시 세종시  127.324362  36.528559  2020
# 2     2020-12-31  18:16  세종특별자치시 세종시  127.328889  36.524532  2020
# 3     2020-12-31  18:10       대전 대덕구  127.479598  36.475791  2020
# 4     2020-12-31  18:00  세종특별자치시 세종시  127.238288  36.470593  2020
# ...          ...    ...          ...         ...        ...   ...
# 9476  2022-01-01  10:15       충남 청양군  126.800164  36.449393  2022
# 9477  2022-01-01  10:06       강원 강릉시  128.904923  37.770272  2022
# 9478  2022-01-01  08:09   경기 용인시 기흥구  127.098973  37.308128  2022
# 9479  2022-01-01  06:24   경기 용인시 기흥구  127.071588  37.240608  2022
# 9480  2022-01-01  01:51       경기 안성시  127.213912  37.094572  2022
#
# [9481 rows x 9 columns]

# %% [markdown]
# ## 로드킬 그리드 생성

# %%
# 1. 위도/경도 범위
min_lat, max_lat = 33.00, 38.50
min_lon, max_lon = 126.00, 130.00

# 2. 격자 크기 설정 (0.1도 ≈ 10~11km)
grid_size = 0.3

# 3. 격자 생성
grid_cells = []
grid_ids = []
grid_id = 1

lon = min_lon
while lon < max_lon:
    lat = min_lat
    while lat < max_lat:
        cell = box(lon, lat, lon + grid_size, lat + grid_size)
        grid_cells.append(cell)
        grid_ids.append(f'grid_{grid_id}')
        grid_id += 1
        lat += grid_size
    lon += grid_size

# 4. GeoDataFrame으로 변환
grid = gpd.GeoDataFrame({'grid_id': grid_ids, 'geometry': grid_cells}, crs='EPSG:4326')

# %% [markdown]
# ## 그리드에 로드킬 빈도수 넣기(dict)

# %%
# 결과 저장용 딕셔너리: grid_id → 포함된 좌표 개수
grid_counts = defaultdict(int)
grid_list = []

# df에 '위도', '경도' 열이 있다고 가정
for i, row in rk_df.iterrows():  # i는 인덱스, row는 한 줄
    lat = row['위도']
    lon = row['경도']

    # 각 격자(box) 범위 안에 포함되는지 확인
    for grid_id, cell in zip(grid_ids, grid_cells):
        minx, miny, maxx, maxy = cell.bounds
        if miny <= lat < maxy and minx <= lon < maxx:
            grid_counts[grid_id] += 1
            grid_list.append(grid_id)
            break  # 이미 해당하는 격자 찾았으면 멈춰

# %%
# 확인용
# grid_counts

# %%
# 원하는 그리드 넘버
list_key = []   #> 그리드 넘버
list_val = []   #> 그리드 넘버에 해당하는 로드킬 수
for key, val in grid_counts.items():
    if val <= 10: #> 로드킬 수 n회 이하
        list_key.append(key)
        list_val.append(val)

# %%
# grid 파생 컬럼 추가
rk_df['grid'] = grid_list

# %%
rk_df = rk_df[['grid', '경도', '위도', '연도']]

# %%
rk_df['grid'].value_counts()
# Out:
# grid
# grid_73     834
# grid_72     726
# grid_54     587
# grid_71     528
# grid_53     513
#            ...
# grid_203      2
# grid_62       1
# grid_100      1
# grid_217      1
# grid_14       1
# Name: count, Length: 143, dtype: int64

# %% [markdown]
# ## 로드킬 map 그리기(mp)

# %%
map_center = [37.5665, 126.9780]
mp = folium.Map(location=map_center, zoom_start=12, tiles='OpenStreetMap')

# %%
for grid_num in list_key[:5]:
    for idx, row in rk_df[rk_df['grid'] == grid_num].iterrows():
        folium.Marker(
            location=[row['위도'], row['경도']],
            popup=row.get('name', f"위도: {row['위도']}, 경도: {row['경도']}"),
            tooltip=row.get('name', '포인트'),
        icon=folium.Icon(color='black', icon='info-sign')).add_to(mp)

# %%
mp
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fbec0dced6b3500e0c37d2b197624dde {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fbec0dced6b3500e0c37d2b197624dde&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fbec0dced6b3500e0c37d2b197624dde = L.map(
#                 &quot;map_fbec0dced6b3500e0c37d2b197624dde&quot;,
#                 {
#                     center: [37.5665, 126.978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_123e6a3f1af74619872730cf13bfe931 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_123e6a3f1af74619872730cf13bfe931.addTo(map_fbec0dced6b3500e0c37d2b197624dde);
#
#
#             var marker_f9249090ec17ef22f08499338b3cae0c = L.marker(
#                 [34.40607717278012, 126.57809814306064],
#                 {
# }
#             ).addTo(map_fbec0dced6b3500e0c37d2b197624dde);
#
#
#             var icon_9f277f44a15685d9fb65e5fde20fb3a4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_06c105d5c68e2e838fefddc45d1619fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f39b86bec3b5e09d0d47faad8b6ef9f = $(`&lt;div id=&quot;html_9f39b86bec3b5e09d0d47faad8b6ef9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;위도: 34.40607717278012, 경도: 126.57809814306064&lt;/div&gt;`)[0];
#                 popup_06c105d5c68e2e838fefddc45d1619fe.setContent(html_9f39b86bec3b5e09d0d47faad8b6ef9f);
#
#
#
#         marker_f9249090ec17ef22f08499338b3cae0c.bindPopup(popup_06c105d5c68e2e838fefddc45d1619fe)
#         ;
#
#
#
#
#             marker_f9249090ec17ef22f08499338b3cae0c.bindTooltip(
#                 `&lt;div&gt;
#                      포인트
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_f9249090ec17ef22f08499338b3cae0c.setIcon(icon_9f277f44a15685d9fb65e5fde20fb3a4);
#
#
#             var marker_f0b53b41b8f2080a88f3d5933cad1c0e = L.marker(
#                 [34.4694296007085, 126.50396470954796],
#                 {
# }
#             ).addTo(map_fbec0dced6b3500e0c37d2b197624dde);
#
#
#             var icon_c6b4cc3348491329567d8b0fa0e81036 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e137cfff0d4c15316fcf026c304c53d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47097f56a4630268b6c590c8e3f9c00c = $(`&lt;div id=&quot;html_47097f56a4630268b6c590c8e3f9c00c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;위도: 34.4694296007085, 경도: 126.50396470954796&lt;/div&gt;`)[0];
#                 popup_e137cfff0d4c15316fcf026c304c53d5.setContent(html_47097f56a4630268b6c590c8e3f9c00c);
#
#
#
#         marker_f0b53b41b8f2080a88f3d5933cad1c0e.bindPopup(popup_e137cfff0d4c15316fcf026c304c53d5)
#         ;
#
#
#
#
#             marker_f0b53b41b8f2080a88f3d5933cad1c0e.bindTooltip(
#                 `&lt;div&gt;
#                      포인트
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_f0b53b41b8f2080a88f3d5933cad1c0e.setIcon(icon_c6b4cc3348491329567d8b0fa0e81036);
#
#
#             var marker_2c227f624abf00d30596ce17e37e7555 = L.marker(
#                 [34.44451358090347, 126.36400625739262],
#                 {
# }
#             ).addTo(map_fbec0dced6b3500e0c37d2b197624dde);
#
#
#             var icon_642f4ba2e2f466bc94df0bfe0bcabc3b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_70af75f9c1b006f42c372b93764cb06b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c10e2fee0823d02830d938c20530074c = $(`

# %% [markdown]
# # 생태 통로

# %% [markdown]
# ## 생태 통로 데이터 생성

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/중간 프로젝트/장소(생태통로) 예측 자료/생태통로 시설정보 목록.xlsx'

# %%
# eco road?
er_df = pd.read_excel(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2456021375.py in <cell line: 0>()
#       1 # eco road?
# ----> 2 er_df = pd.read_excel(file_path)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548                 ext = "xls"
#    1549             else:
# -> 1550                 ext = inspect_excel_format(
#    1551                     content_or_path=path_or_buffer, storage_options=storage_options
#    1552                 )
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1400         content_or_path = BytesIO(content_or_path)
#    1401
# -> 1402     with get_handle(
#    1403         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404     ) as handle:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/중간 프로젝트/장소(생태통로) 예측 자료/생태통로 시설정보 목록.xlsx'

# %%
er_df = er_df[['생태통로 유형', '관리기관', '위도', '경도']]

# %%
er_df

# %% [markdown]
# ## 생태 통로 그리드 생성

# %%
# 1. 위도/경도 범위
min_lat2, max_lat2 = 33.00, 38.50
min_lon2, max_lon2 = 126.00, 130.00

# 2. 격자 크기 설정 (0.1도 ≈ 10~11km)
grid_size2 = 0.3

# 3. 격자 생성
grid_cells2 = []
grid_ids2 = []
grid_id2 = 1

lon2 = min_lon2
while lon2 < max_lon2:
    lat2 = min_lat2
    while lat2 < max_lat2:
        cell2 = box(lon2, lat2, lon2 + grid_size2, lat2 + grid_size2)
        grid_cells2.append(cell2)
        grid_ids2.append(f'grid_{grid_id2}')
        grid_id2 += 1
        lat2 += grid_size2
    lon2 += grid_size2

# 4. GeoDataFrame으로 변환
grid2 = gpd.GeoDataFrame({'grid_id': grid_ids2, 'geometry': grid_cells2}, crs='EPSG:4326')

# %% [markdown]
# ## 그리드에 생태 통로 빈도수 넣기(dict)

# %%
# 결과 저장용 딕셔너리: grid_id → 포함된 좌표 개수
grid_counts2 = defaultdict(int)
grid_list2 = []

# df에 '위도', '경도' 열이 있다고 가정
for i, row in er_df.iterrows():  # i는 인덱스, row는 한 줄
    lat2 = row['위도']
    lon2 = row['경도']

    # 각 격자(box) 범위 안에 포함되는지 확인
    for grid_id2, cell2 in zip(grid_ids2, grid_cells2):
        minx, miny, maxx, maxy = cell2.bounds
        if miny <= lat2 < maxy and minx <= lon2 < maxx:
            grid_counts2[grid_id2] += 1
            grid_list2.append(grid_id2)
            break  # 이미 해당하는 격자 찾았으면 멈춰

# %%
# 원하는 그리드 넘버
list_key2 = []   #> 그리드 넘버
list_val2 = []   #> 그리드 넘버에 해당하는 로드킬 수
for key, val in grid_counts2.items():
    if val <= 10: #> 로드킬 수 n회 이하
        list_key.append(key)
        list_val.append(val)

# %%
# grid 파생 컬럼 추가
er_df['grid'] = grid_list2

# %%
er_df

# %% [markdown]
# ## 생태 통로 map 그리기(mp2) -> 로드킬이랑 같이 볼거면 mp로 바꾸기

# %%
map_center2 = [37.5665, 126.9780]
mp2 = folium.Map(location=map_center, zoom_start=12, tiles='OpenStreetMap')

# %%
for grid_num in list_key[:5]:
    for idx, row in er_df[er_df['grid'] == grid_num].iterrows():
        folium.Marker(
            location=[row['위도'], row['경도']],
            popup=row.get('name', f"위도: {row['위도']}, 경도: {row['경도']}"),
            tooltip=row.get('name', '포인트'),
        icon=folium.Icon(color='black', icon='info-sign')).add_to(mp2)

# %%
mp2

# %% [markdown]
# # 그리드 별 생태 통로 수, 로드킬 수 DataFrame

# %%
df = pd.DataFrame()

# %%
grid_list = []
for i in range(251):
    name = f'grid_{i}'
    grid_list.append(name)

# %%
df['그리드'] = grid_list

# %%
df

# %% [markdown]
# ## 로드킬 grid_counts dict -> DataFrame

# %%
rk_dict_df = pd.DataFrame()

# %%
rk_dict_df['그리드'] = grid_counts.keys()
rk_dict_df['로드킬 수'] = grid_counts.values()

# %%
rk_dict_df

# %% [markdown]
# ## 생태통로 grid_counts2 dict -> DataFrame

# %%
er_dict_df = pd.DataFrame()

# %%
er_dict_df['그리드'] = grid_counts2.keys()
er_dict_df['생태통로 수'] = grid_counts2.values()

# %%
er_dict_df

# %% [markdown]
# ## tot_df --> df, rk_dict_df, er_dict_df 합치기

# %%
tot_df = df.merge(rk_dict_df, how='left').merge(er_dict_df, how='left')

# %%
tot_df.sort_values(by='로드킬 수', ascending=False)

# %%
tot_df.info()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import box

# 1. 남한 위도/경도 범위
min_lat, max_lat = 33.0, 38.5
min_lon, max_lon = 126.0, 130.0

# 2. 6x20 그리드
rows, cols = 6, 20
lat_step = (max_lat - min_lat) / rows
lon_step = (max_lon - min_lon) / cols

# 3. 사각형 폴리곤 생성
grid_cells = []
for i in range(rows):
    for j in range(cols):
        lat1 = min_lat + i * lat_step
        lat2 = lat1 + lat_step
        lon1 = min_lon + j * lon_step
        lon2 = lon1 + lon_step
        grid_cells.append(box(lon1, lat1, lon2, lat2))

grid = gpd.GeoDataFrame({'geometry': grid_cells})

# 4. 지도(배경)와 함께 시각화
fig, ax = plt.subplots(figsize=(6, 8))

# 남한 shapefile이 있으면 추가 가능 (없으면 grid만 그림)
# korea = gpd.read_file("KOR_adm0.shp")
# korea.plot(ax=ax, color='white', edgecolor='black')

grid.boundary.plot(ax=ax, color="red", linewidth=0.5)
plt.title("남한 위 6x20 그리드")
plt.show()
